# %%
import sys; sys.path.append(_dh[0].split("knowknow")[0])
from knowknow import *

database_name = 'wos'

# %%
groups = load_variable("%s.groups"%database_name)
cits = get_cnt("%s.doc"%database_name, ['c'])
# Out:
# Loaded keys: dict_keys(['c'])
# Available keys: ['fj', 'fy', 'ty', 'fy.ty', 'fj.ty', 'jy', 'a', 'ay', 'aj', 'ajy', 'ac', 'c', 'cy', 'cj', 'cjy']

# %%
import json
for i in range(50):
    print("\n".join(
        "%s (%s)" % (k,cits['c'][k]) for k,v in groups.items() 
        if v==i
    ))
    print()
# Out:
# andrews|social indicators we (374)
# andrews|social indicators re (0)
# andrews|1991| measures personality, v1, p61 (0)
#
# campbell|quality am life perc (0)
# campell|quality am life perc (0)
# campbell|quality am life (514)
# campbell|quality life am (0)
# campbell|quality am life 1978 (0)
# brebner|1995| pers indiv differ, v19, p251 (0)
#
# costa|revised neo personal (41)
# cha|2003| soc indic res, v62-3, p455 (0)
#
# cummins|austr unity wellbein (18)
# cummins|2002| universality subject, p7 (0)
#
# diener|well being fdn hedon (99)
# davern|2007| j happiness stud, v8, p429 (0)
#
# gurin|am view their mental (270)
# deneve|1998| psychol bull, v124, p197 (0)
#
# headey|understanding happin (57)
# heady|understanding happin (0)
# diener|1996| j res pers, v30, p389 (0)
#
# international|pers wellb ind (0)
# international|pers wellb ind ad pw (0)
# international|pers wellb ind man (0)
# international|pers wellb ind ad (0)
# diener|1996| psychol sci, v7, p181 (65)
#
# kline|principles practice (407)
# kline|principles practices (0)
# kline|principals practice (0)
# kline|principles practise (0)
# kline|principles and pract (0)
# diener|2003| annu rev psychol, v54, p403 (0)
#
# tabachnick|using multivariate s (0)
# tabachnick|using multivariate a (0)
# tabachnik|using multivariate s (0)
# diener|1984| psychol bull, v95, p542 (690)
#
# thompson|exploratory confirma (0)
# diener|1994| soc indic res, v31, p103 (93)
#
# bellah|habits heart individ (0)
# bellah|habits heart (0)
# bellah|habits heart middle (0)
# bellah|habits heart intro u (0)
# bellah|habits hearts indivi (0)
# bellah|habits of heart (0)
# diener|1999| psychol bull, v125, p276 (896)
#
# blanchflower|warwick ec res paper (0)
# gosling|2003| j res pers, v37, p504 (23)
#
# easterlin|nations households e (144)
# easterlin|nation households ec (0)
# easterlin|nations household ec (0)
# headey|1989| j pers soc psychol, v57, p731 (0)
#
# hagenaars|poverty stat late 19 (24)
# hills|2001| pers indiv differ, v30, p595 (0)
#
# hooghe|technical report soc (0)
# hu|1999| struct equ modeling, v6, p1 (405)
#
# inglehart|modernization postmo (388)
# inglehart|modernisation postmo (0)
# inglehart|modernization cultur (0)
# john|1999| hdb personality theo, p102 (0)
#
# nussbaum|fragility goodness l (0)
# nussbaum|fragility goodness (0)
# lucas|1996| j pers soc psychol, v71, p616 (86)
#
# oecd|soc glanc oecd soc i (0)
# oecd|soc glanc (0)
# oecd|soc glanc 2009 oecd (0)
# oecd|soc glanc 2011 oecd (0)
# oecd|ed glanc 2011 oecd i (0)
# oecd|ed glanc 2008 oecd i (0)
# oecd|ed glanc 2010 (0)
# oecd|ed glanc 2012 oecd i (0)
# oecd|ed glanc 2015 (0)
# oecd|ed glanc 2017 oecd i (0)
# oecd|ed glanc 2007 oecd i (0)
# oecd|ed glanc oecd ind (0)
# oecd|ed glanc 2015 oecd i (0)
# oecd|hlth glanc 2015 oecd (0)
# oecd|hlth glanc 2011 oecd (0)
# oecd|hlth glanc 2013 oecd (0)
# oecd|ed glanc 2013 oecd i (0)
# [oecd|ed glanc 2014 oecd i (0)
# oecd|ed glanc 2014 (0)
# oecd|ed glanc 2013 (0)
# oecd|ed glanc 2009 (0)
# oecd|ed glanc oecd ind 19 (0)
# michalos|1985| soc indic res, v16, p347 (209)
#
# putnam|bowling alone collap (1353)
# putnam|bowling alone (0)
# putnam|bowling alone civic (0)
# puttnam|bowling alone (0)
# putnam|bowling alone am dec (0)
# putnam|bowling along collap (0)
# putnam|bowling collapse rev (0)
# putnam|bowling alone the co (0)
# michalos|1983| soc indic res, v13, p225 (0)
#
# putnam|making democracy wor (593)
# putnam|making democracy (0)
# putnam|making social democr (0)
# michalos|1982| soc indic res, v11, p1 (0)
#
# snijders|multilevel anal intr (492)
# snijders|multilevel anal (0)
# snijders|intro multilevel ana (0)
# snijders|multilevel analysis (0)
# snijders|multilevel modeling (0)
# michalos|1980| soc indic res, v8, p385 (0)
#
# suh|culture subjective w (0)
# myers|1995| psychol sci, v6, p10 (72)
# myers|1995| psychol sci, v6, p11 (0)
#
# ben-arieh|measuring monitoring (0)
# pavot|1991| j pers assess, v57, p149 (55)
#
# berg|qualitative res meth (189)
# russell|1999| j pers soc psychol, v76, p805 (0)
#
# bohm|companion qualitativ (0)
# russell|2003| psychol rev, v110, p145 (17)
#
# dey|qualitative data ana (0)
# schawarz|1999| well being fdn hedon, p61 (60)
# schwarz|1999| well being fdn hedon, p61 (0)
# schwartz|1999| well being fdn hedon, p61 (0)
#
# holsti|content anal social (69)
# schwarz|1987| eur j soc psychol, v17, p69 (0)
#
# mayring|companion qualitativ (0)
# vitterso|2001| pers indiv differ, v31, p903 (6)
#
# messick|ed measurement (13)
# yik|1999| j pers soc psychol, v77, p600 (0)
#
# michalos|global report studen (68)
# bjornskov|2008| appl res qual life, v3, p43 (0)
#
# neuendorf|content anal guidebo (55)
# christoph|2003| social indicators re, v64, p521 (0)
#
# sirken|cognition survey res (0)
# clark|1994| econ j, v104, p648 (100)
#
# willis|cognitive interviewi (0)
# cummins|1995| soc indic res, v35, p179 (69)
#
# zumbo|concept of validity: revisions (0)
# di|2001| am econ rev, v91, p335 (80)
#
# almond|civic culture politi (0)
# almond|civic culture (428)
# almond|civic culture revisi (0)
# almond|civic cult (0)
# almond|civil culture (0)
# almond|the civil culture (0)
# diener|1995| j pers soc psychol, v69, p851 (0)
#
# bendix|nation building citi (0)
# bendix|national building ci (0)
# diener|2000| am psychol, v55, p34 (238)
#
# bernard|f09 cprn (0)
# dolan|2008| j econ psychol, v29, p94 (116)
#
# brubaker|citizenship nationho (171)
# duncan|1995| j epidemiol commun h, v49, p290 (0)
#
# council|conc dev soc coh ind (0)
# easterlin|1995| j econ behav organ, v27, p35 (133)
#
# cramer|adv quantitative dat (0)
# eckersley|2009| soc indic res, v94, p1 (8)
#
# dahl|pluralist democracy (34)
# farrell|2004| j community psychol, v32, p9 (0)
#
# dalton|democratic challenge (40)
# fernandez|1981| am sociol rev, v46, p840 (0)
#
# deutsch|nation building (0)
# frey|2002| j econ lit, v40, p402 (148)
#
# dickes|ntts sem new techn t (0)
# frey|2000| econ j, v110, p918 (64)
#
# durkheim|division labor soc (1103)
# durkheim|division labor (0)
# durkheim|division labour (0)
# durkheim|division lab soc (0)
# durkheim|division labor socie (0)
# durkheim|divions labor soc (0)
# durkheim|divison labor soc (0)
# durkheim|division labour soci (0)
# durkeim|division labour soc (0)
# durkheim|division labor soc t (0)
# dukheim|division labor soc (0)
# gutierrez|2005| pers indiv differ, v38, p1561 (0)
#
# esping|3 worlds welfare cap (14)
# hayes|2003| pers indiv differ, v34, p723 (0)
#
# green|comp j comp int ed (0)
# helliwell|2004| philos t r soc b, v359, p1435 (91)
#
# green|llakes ctr res paper (0)
# helliwell|2003| econ model, v20, p331 (70)
#
# green|ed equality social c (0)
# hooghe|2009| comp polit stud, v42, p198 (47)
